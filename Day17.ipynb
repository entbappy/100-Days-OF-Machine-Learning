# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=98d1ea87033bb6096878a9854c1fccb5&language=en-US&page=1')

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/gNBCvtYyGPbjPCT1k3MvJuNuXR6.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 19404,
#   'original_language': 'hi',
#   'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#   'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#   'popularity': 16.133,
#   'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#   'release_date': '1995-10-20',
#   'title': 'Dilwale Dulhania Le Jayenge',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 3070},
#  {'adult': False,
#   'backdrop_path': '/iNh3BivHyg5sQRPP1KOkzguEX0H.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path            genre_ids      id  \
# 0   False  /gNBCvtYyGPbjPCT1k3MvJuNuXR6.jpg      [35, 18, 10749]   19404
# 1   False  /iNh3BivHyg5sQRPP1KOkzguEX0H.jpg             [18, 80]     278
# 2   False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg             [18, 80]     238
# 3   False  /jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg              [10749]  724089
# 4   False  /fQq1FWp1rC89xDrRMuyFJdFUdMd.jpg          [10749, 35]  761053
# 5   False  /w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg              [10749]  696374
# 6   False  /lQAe1hfWYDdYypRVdzTbdg6JYWP.jpg                 [18]  526702
# 7   False  /loRmRzQXZeqG78TqZuyvSlEQfZb.jpg      [18, 36, 10752]     424
# 8   False  /poec6RqOKY9iSiIUmfyfPfiLtvB.jpg             [18, 80]     240
# 9   False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg      [10749, 16, 18]  372058
# 10  False  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg      [16, 10751, 14]     129
# 11  False   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg         [35, 53, 18]  496243
# ...

# %%
test = pd.DataFrame(response.json()['results'], columns=['id','title','overview','release_date','popularity','vote_average','vote_count'])
test.head()
# Out:
#        id                        title  \
# 0   19404  Dilwale Dulhania Le Jayenge
# 1     278     The Shawshank Redemption
# 2     238                The Godfather
# 3  724089    Gabriel's Inferno Part II
# 4  761053   Gabriel's Inferno Part III
#
#                                             overview release_date  popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      16.133
# 1  Framed in the 1940s for the double murder of h...   1994-09-23      49.826
# 2  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      49.078
# 3  Professor Gabriel Emerson finally learns the t...   2020-07-31       6.459
# 4  The final part of the film adaption of the ero...   2020-11-19      14.270
#
#    vote_average  vote_count
# 0           8.7        3070
# 1           8.7       19378
# 2           8.7       14604
# 3           8.7        1290
# 4           8.7         849

# %%
test.shape
# Out:
# (20, 7)

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,431):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=98d1ea87033bb6096878a9854c1fccb5&language=en-US&page={}'.format(i))
    data = pd.DataFrame(response.json()['results'], columns=['id','title','overview','release_date','popularity','vote_average','vote_count'])
    df = df.append(data)

# %%
df
# Out:
#         id                          title  \
# 0    19404    Dilwale Dulhania Le Jayenge
# 1      278       The Shawshank Redemption
# 2   724089      Gabriel's Inferno Part II
# 3      238                  The Godfather
# 4   761053     Gabriel's Inferno Part III
# ..     ...                            ...
# 1    74849  The Star Wars Holiday Special
# 2     5491              Battlefield Earth
# 3    14164           Dragonball Evolution
# 4    11059              House of the Dead
# 5    40016     Birdemic: Shock and Terror
#
#                                              overview release_date  \
# 0   Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# 1   Framed in the 1940s for the double murder of h...   1994-09-23
# 2   Professor Gabriel Emerson finally learns the t...   2020-07-31
# 3   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 4   The final part of the film adaption of the ero...   2020-11-19
# ...

# %%
import requests

url = "https://weatherbit-v1-mashape.p.rapidapi.com/current"

querystring = {"lon":"38.5","lat":"-78.5"}

headers = {
    'x-rapidapi-key': "156877d1e1msh6806b57dfec44b9p1bd2c8jsn796f2ff15790",
    'x-rapidapi-host': "weatherbit-v1-mashape.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

data = response.json()

# %%
data['data']
# Out:
# [{'rh': 100,
#   'pod': 'n',
#   'lon': 38.5,
#   'pres': 594.5,
#   'timezone': 'Indian/Kerguelen',
#   'ob_time': '2021-04-07 19:34',
#   'country_code': 'TF',
#   'clouds': 100,
#   'ts': 1617824087,
#   'solar_rad': 0,
#   'state_code': '03',
#   'city_name': 'Port-aux-Français',
#   'wind_spd': 3.79487,
#   'wind_cdir_full': 'west-southwest',
#   'wind_cdir': 'WSW',
#   'slp': 1048,
#   'vis': 11,
#   'h_angle': -90,
#   'sunset': '13:10',
#   'dni': 0,
#   'dewpt': -76.5,
#   'snow': 0,
#   'uv': 0,
#   'precip': 0,
#   'wind_dir': 251,
#   'sunrise': '05:29',
#   'ghi': 0,
#   'dhi': 0,
#   'aqi': None,
#   'lat': -78.5,
#   'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast Clouds'},
#   'datetime': '2021-04-07:19',
#   'temp': -61.5,
#   'station': 'C9300',
#   'elev_angle': -17.41,
#   'app_temp': -81.8}]

# %%
df = pd.DataFrame(data['data'])

# %%
df
# Out:
#     rh pod   lon   pres          timezone           ob_time country_code  \
# 0  100   n  38.5  594.5  Indian/Kerguelen  2021-04-07 19:34           TF
#
#    clouds          ts  solar_rad  ... ghi dhi   aqi   lat  \
# 0     100  1617824087          0  ...   0   0  None -78.5
#
#                                              weather       datetime  temp  \
# 0  {'icon': 'c04n', 'code': 804, 'description': '...  2021-04-07:19 -61.5
#
#    station elev_angle  app_temp
# 0    C9300     -17.41     -81.8
#
# [1 rows x 36 columns]
